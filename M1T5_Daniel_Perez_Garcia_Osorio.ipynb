# %% [markdown]
# Tema 5. Colecciones en Python

# %% [markdown]
# Listas y Tuplas
# Crea una lista y una tupla (≥ 3 strings) de temática libre y realiza:
# - Muestra la lista y la tupla.
# - Muestra el segundo elemento de la lista y el penúltimo de la tupla.
# - Modifica (si se puede) algún elemento de la lista y de la tupla y muestra el resultado.
# - Muestra el tamaño de la lista y de la tupla con len().
# - Realiza una búsqueda de un elemento con el operador in y muestra si devuelve True o False.
# - Añade (si se puede) un elemento a la lista y a la tupla y verifica el cambio.
# - Borra o elimina (si se puede) el contenido de la lista y de la tupla y verifica el cambio.

# %%
# Lista y tupla

''' Una lista es una colección ordenada y modificable de elementos.
Sus características principales son:
Mantiene el orden de los elementos.
Permite elementos duplicados.
Es mutable: podemos cambiar, añadir o eliminar elementos.
Se define con corchetes: [].'''

# Podemos hacer una lista numerica, no importa si se repite algún elemento
lista_numerica = [1, 2, 3, 4, 4, 5]
print(lista_numerica)

# Tambien puede ser una lista de texto
lista_texto = ["Pepito", "Manolito", "Juanito"]
print(lista_texto)

# O incluso puede ser mixta
lista_mixta = [1, "Pepito", 3.14, True]
print(lista_mixta)

# Podemos mutar la lista, por ejemplo, cambiando un elemento
lista_numerica[0] = 10
print(lista_numerica)

# también podemos eliminar un elemento
del lista_texto[2]
print(lista_texto)
# Out:
# [1, 2, 3, 4, 4, 5]
# ['Pepito', 'Manolito', 'Juanito']
# [1, 'Pepito', 3.14, True]
# [10, 2, 3, 4, 4, 5]
# ['Pepito', 'Manolito']

# %% [markdown]
# Sets y Diccionarios
#
# - Crea un set (≥ 3 strings) y un diccionario (≥ 3 pares clave:valor) y realiza:
# - Muestra el set y el diccionario.

# %%
escuderia_f1 = {"Mercedes", "Red Bull", "Ferrari", "McLaren", "Alpine"}

informacion_usuario = {
    "nombre": "Max Verstappen",
    "edad": 28,
    "pais": "Belgica",
    "profesion": "Piloto de F1"
}

print("mi set", escuderia_f1)
print("mi diccionario", informacion_usuario)
# Out:
# mi set {'Red Bull', 'Ferrari', 'Mercedes', 'Alpine', 'McLaren'}
# mi diccionario {'nombre': 'Max Verstappen', 'edad': 28, 'pais': 'Belgica', 'profesion': 'Piloto de F1'}

# %% [markdown]
# - Muestra (si se puede) el segundo elemento del set y el valor del primer par del diccionario.
# - Modifica (si se puede) algún elemento y muestra el resultado.

# %%
'''En el caso del set, es una colección desordenada y no indexada 
de elementos únicos. No podemos acceder a los elementos mediante un índice,
 y no permite elementos duplicados.'''

# En el caso del diccionario

informacion_usuario = {
    "nombre": "Max Verstappen",
    "edad": 28,
    "pais": "Belgica",
    "profesion": "Piloto de F1"
}

datos_1_y_2 = informacion_usuario.get("nombre"), informacion_usuario.get("edad")

print(datos_1_y_2)
# Out:
# ('Max Verstappen', 28)

# %% [markdown]
# - Muestra el tamaño de ambos con len().
# - Haz una búsqueda en ambos (con in para set y in/.get() para diccionario).
# - Añade (si se puede) un elemento al set (.add()) y un par clave–valor al diccionario (dic["clave"] = valor).
# - Borra o elimina (si se puede) el contenido de ambos (.clear()).
